# %%
import Vision as v
import os
import numpy as np
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="c6d9c1b9-4842-4ec6-a6ad-fd03e09bfe38" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
data_1 = 'dataset/nat006.csv'  
data_2 = 'dataset/nat006_bis.csv' 
data_3 = 'dataset/nat006_ter.csv' 

image_ref = 'dataset/nat006.bmp'

# %%
v.AoI_sequences(data_1,
               sampling_frequency=256,
               size_plan_x = 921,
               size_plan_y = 630, 
               display_scanpath=False, 
               verbose=False,
               ref_image = image_ref,
               AoI_identification_method = 'I_AP')

# %%
v.AoI_sequences(data_2,
               sampling_frequency=256,
               size_plan_x = 921,
               size_plan_y = 630, 
               display_scanpath=False, 
               verbose=False,
               ref_image = image_ref,
               AoI_identification_method = 'I_AP')

# %%
v.AoI_sequences(data_3,
               sampling_frequency=256,
               size_plan_x = 921,
               size_plan_y = 630, 
               display_scanpath=False, 
               verbose=False,
               ref_image = image_ref,
               AoI_identification_method = 'I_AP')

# %%
aoi_seqs = v.AoI_sequences([data_1, data_2, data_3], 
                               sampling_frequency=256,
                               size_plan_x = 921,
                               size_plan_y = 630, 
                               display_scanpath=False, 
                               verbose=False,
                               ref_image = image_ref,
                               AoI_identification_method = 'I_AP')

# %%
results = v.AoI_longest_common_subsequence(aoi_seqs, 
           verbose=False)
print(repr(results))
# Out:
# {'AoI_longest_common_subsequence_matrix': array([[0.        , 0.26351351, 0.32432432],
#        [0.26351351, 0.        , 0.32638889],
#        [0.32432432, 0.32638889, 0.        ]]), 'AoI_longest_common_subsequence_pairs': {(0, 1): ['L', 'F', 'F', 'F', 'L', 'F', 'F', 'L', 'O', 'O', 'O', 'A', 'I', 'I', 'I', 'I', 'I', 'C', 'K', 'F', 'F', 'A', 'A', 'F', 'O', 'B', 'B', 'I', 'M', 'M', 'O', 'G', 'E', 'E', 'E', 'O', 'O', 'A', 'A'], (0, 2): ['L', 'L', 'F', 'F', 'F', 'F', 'F', 'F', 'G', 'G', 'O', 'O', 'A', 'O', 'O', 'O', 'B', 'B', 'A', 'A', 'A', 'A', 'A', 'F', 'F', 'D', 'D', 'N', 'N', 'K', 'F', 'G', 'G', 'F', 'F', 'O', 'O', 'O', 'A', 'A', 'A', 'A', 'A', 'O', 'F', 'G', 'G', 'O'], (1, 2): ['L', 'O', 'F', 'F', 'G', 'F', 'F', 'F', 'F', 'L', 'L', 'L', 'O', 'A', 'M', 'M', 'M', 'M', 'M', 'M', 'G', 'F', 'A', 'E', 'E', 'I', 'L', 'L', 'L', 'L', 'L', 'L', 'F', 'F', 'O', 'G', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'L', 'K', 'K', 'K']}}

# %%
results = v.AoI_smith_waterman(aoi_seqs, 
           verbose=False)
print(repr(results))
# Out:
# {'AoI_smith_waterman_matrix': array([[0.00000000e+00, 1.38801976e-01, 6.66072806e-05],
#        [1.38801976e-01, 0.00000000e+00, 3.11170376e-05],
# ...

# %%
results = v.AoI_trend_analysis(aoi_seqs, 
           verbose=False)
print(repr(results))
# Out:
# {'AoI_trend_analysis_common_subsequence': ['O', 'F', 'L', 'G', 'O', 'F', 'A', 'F', 'G', 'F', 'O', 'C', 'A', 'N', 'K', 'L', 'M', 'I', 'O', 'B', 'O', 'G', 'L', 'A', 'L', 'D', 'H', 'E', 'K', 'F', 'A', 'O', 'E', 'B', 'K', 'B', 'M', 'G', 'I', 'A', 'N', 'O', 'K', 'A', 'I', 'B']}

# %%
results = v.AoI_eMine(aoi_seqs, 
           verbose=False)
print(repr(results))
# Out:
# {'AoI_eMine_common_subsequence': ['L', 'F', 'F', 'F', 'F', 'F', 'F', 'L', 'L', 'L', 'O', 'A', 'M', 'M', 'M', 'M', 'M', 'G', 'A', 'E', 'E', 'F', 'F', 'G', 'O']}
